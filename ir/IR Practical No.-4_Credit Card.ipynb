# %% [markdown]
# # IR Practical No.-4
#
# Implement Agglomerative hierarchical clustering algorithm using appropriate dataset.

# %%
# Out:
# ^C

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
import scipy.cluster.hierarchy as shc

# %%
df = pd.read_csv(r"CC GENERAL.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df = df.drop(columns=["CUST_ID"])
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
# ...

# %%
df["MINIMUM_PAYMENTS"].fillna(df["MINIMUM_PAYMENTS"].mean(), inplace=True)
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_26992\2652015822.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["MINIMUM_PAYMENTS"].fillna(df["MINIMUM_PAYMENTS"].mean(), inplace=True)

# %%
df["CREDIT_LIMIT"].fillna(df["CREDIT_LIMIT"].mean(), inplace=True)
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_26992\2005471383.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["CREDIT_LIMIT"].fillna(df["CREDIT_LIMIT"].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)
df_norm = normalize(df_scaled)
df_norm = pd.DataFrame(df_norm)
df_norm
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.311938 -0.106297 -0.181072 -0.152108 -0.148760 -0.198921 -0.343687
# 1     0.219925  0.037539 -0.131222 -0.099749 -0.127037  0.728166 -0.341434
# 2     0.126682  0.146783 -0.030504  0.030850 -0.128790 -0.132249  0.359771
# 3     0.020589 -0.426439  0.097309  0.229034 -0.190618 -0.154587 -0.425253
# 4    -0.151595  0.218909 -0.195238 -0.146744 -0.192075 -0.197234 -0.428504
# ...        ...       ...       ...       ...       ...       ...       ...
# 8945 -0.146893  0.103128 -0.066344 -0.071050 -0.026403 -0.092916  0.252770
# 8946 -0.151521  0.105735 -0.067173 -0.072846 -0.025067 -0.095266  0.259162
# 8947 -0.156974 -0.039324 -0.085222 -0.075675 -0.062521 -0.098965  0.181181
# 8948 -0.154320 -0.038411 -0.097240 -0.073918 -0.094139 -0.093057 -0.253016
# 8949 -0.115207 -0.178881  0.008480  0.060711 -0.091465 -0.081732  0.088393
#
# ...

# %%
pca = PCA(n_components=2, random_state=42)
df_2d = pca.fit_transform(df_norm)
df_2d = pd.DataFrame(df_2d, columns=["P1", "P2"])
df_2d.head()
# Out:
#          P1        P2
# 0 -0.489826 -0.679678
# 1 -0.518791  0.545011
# 2  0.330885  0.268978
# 3 -0.482374 -0.092111
# 4 -0.563289 -0.481915

# %%
plt.figure(figsize=(7,7))
plt.title("Dendrogram - Agglomerative (ward)")
shc.dendrogram(shc.linkage(df_2d, method='ward'))
plt.show()

# %%
ac = AgglomerativeClustering(n_clusters=2)
labels = ac.fit_predict(df_2d)

plt.figure(figsize=(6,6))
plt.scatter(df_2d["P1"], df_2d["P2"], c=labels, cmap="rainbow")
plt.title("Agglomerative Clusters (k=2)")
plt.show()

# %%
ac = AgglomerativeClustering(n_clusters=3)
labels = ac.fit_predict(df_2d)

plt.figure(figsize=(6,6))
plt.scatter(df_2d["P1"], df_2d["P2"], c=labels, cmap="rainbow")
plt.title("Agglomerative Clusters (k=3)")
plt.show()

# %%
ac = AgglomerativeClustering(n_clusters=4)
labels = ac.fit_predict(df_2d)

plt.figure(figsize=(6,6))
plt.scatter(df_2d["P1"], df_2d["P2"], c=labels, cmap="rainbow")
plt.title("Agglomerative Clusters (k=4)")
plt.show()

# %%
ac = AgglomerativeClustering(n_clusters=5)
labels = ac.fit_predict(df_2d)

plt.figure(figsize=(6,6))
plt.scatter(df_2d["P1"], df_2d["P2"], c=labels, cmap="rainbow")
plt.title("Agglomerative Clusters (k=5)")
plt.show()

# %%
ac = AgglomerativeClustering(n_clusters=6)
labels = ac.fit_predict(df_2d)

plt.figure(figsize=(6,6))
plt.scatter(df_2d["P1"], df_2d["P2"], c=labels, cmap="rainbow")
plt.title("Agglomerative Clusters (k=6)")
plt.show()

# %%
scores = {}

# Compute silhouette score for k = 2 to 6
for k in [2, 3, 4, 5, 6]:
    ac = AgglomerativeClustering(n_clusters=k)
    labels = ac.fit_predict(df_2d)
    score = silhouette_score(df_2d, labels)
    scores[k] = score
    print(f"Silhouette Score for k={k}: {score:.4f}")
# Out:
# Silhouette Score for k=2: 0.4373
# Silhouette Score for k=3: 0.4167
# Silhouette Score for k=4: 0.3531
# Silhouette Score for k=5: 0.3506
# Silhouette Score for k=6: 0.3178

# %%
plt.figure(figsize=(6,4))
plt.bar(scores.keys(), scores.values())
plt.title("Silhouette Scores for Different k")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.show()

# %% [raw]
# heory:
#
# Hierarchical Clustering is an unsupervised learning algorithm used to group similar data points into clusters based on their distance or similarity.
#
# There are two main types of hierarchical clustering:
#
# Agglomerative (Bottom-Up) — starts with each data point as a single cluster and merges them step by step.
#
# Divisive (Top-Down) — starts with all points in one cluster and splits them iteratively.
#
# In Agglomerative Clustering, each observation begins in its own cluster, and pairs of clusters are merged as one moves up the hierarchy based on linkage criteria such as:
#
# Ward linkage (minimizes variance within clusters)
#
# Complete linkage (max distance between clusters)
#
# Average linkage (average distance between clusters)
#
# The result is often visualized using a Dendrogram, which shows how clusters are merged at each step.
#
# Concepts Used:
#
# Standardization: Scaling features to have zero mean and unit variance.
#
# Normalization: Ensures all data points lie in a similar range, improving distance-based clustering.
#
# Principal Component Analysis (PCA): Reduces dimensions (2D projection for visualization).
#
# Agglomerative Clustering: Groups similar data points hierarchically using linkage.
#
# Silhouette Score: Evaluates how well points fit within their assigned cluster.
#
# Explanation of the Code:
#
# Importing Libraries:
#
# pandas, numpy: For data handling.
#
# matplotlib.pyplot: For plotting graphs.
#
# sklearn.preprocessing: For scaling and normalization.
#
# PCA: For dimensionality reduction.
#
# AgglomerativeClustering: For hierarchical clustering.
#
# silhouette_score: For cluster evaluation.
#
# scipy.cluster.hierarchy: For dendrogram visualization.
#
# Dataset Loading and Cleaning:
#
# Read the dataset CC GENERAL.csv.
#
# Drop the non-numeric column CUST_ID.
#
# Fill missing values in MINIMUM_PAYMENTS and CREDIT_LIMIT with their mean.
#
# Data Preprocessing:
#
# Apply StandardScaler to standardize features.
#
# Apply normalize() to scale the data to unit length.
#
# Dimensionality Reduction:
#
# Use PCA to reduce data to 2 principal components for easy visualization.
#
# Creating the Dendrogram:
#
# Use shc.dendrogram() with Ward linkage to visualize hierarchical merging.
#
# Performing Clustering:
#
# Apply AgglomerativeClustering() with different n_clusters (2 to 6).
#
# Plot results with different colors for each cluster.
#
# Evaluating with Silhouette Score:
#
# For each k (2 to 6), calculate the silhouette score.
#
# Plot a bar chart to compare which k gives the best cluster quality.
#
# Output (Expected):
#
# Dendrogram showing the hierarchical merging of clusters.
#
# Cluster scatter plots for different values of k (2–6).
#
# Silhouette scores printed and shown as a bar chart.
#
# Example Output:
#
# Silhouette Score for k=2: 0.44
# Silhouette Score for k=3: 0.51
# Silhouette Score for k=4: 0.48
# Silhouette Score for k=5: 0.47
# Silhouette Score for k=6: 0.45
#
#
# → The best k is the one with the highest silhouette score.
#
# Conclusion:
#
# Agglomerative Hierarchical Clustering was successfully implemented using the credit card dataset.
# The dendrogram and silhouette score analysis helped determine the optimal number of clusters.
# This technique helps in customer segmentation, pattern recognition, and data grouping without prior class labels.
